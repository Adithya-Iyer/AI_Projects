# %% [markdown]
# # Artificial Intelligence (CS6364-002)
# ## Homework 8 - GRU Part
# ## Submission by - Adithya Sundararajan Iyer (asi200000)

# %% [markdown]
# Revise the code in the tutorial “Sentiment Analysis using LSTM (Step-by-Step Tutorial)” to replace the LSTM with the GRU. The following article provides you an example of GPU for sentiment analysis on a dataset of Amazon reviews.
# https://www.kaggle.com/code/dijiswiki/lstm-gru-sentiment-analysis-on-amazon-review

# %%
from collections import Counter, defaultdict
import matplotlib.pyplot as plt
# %matplotlib inline
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import numpy as np
import pandas as pd
from string import punctuation
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data_frame = pd.read_csv("training.1600000.processed.noemoticon.csv",encoding='latin-1')
# data_frame = data_frame.sample(frac=0.25)

# %%
data_frame.columns = ['labels','time','date','qurey','username','tweet']
data_frame = data_frame.drop(columns =['time','date','qurey','username'], axis=1)
data_frame.head()
# Out:
#    labels                                              tweet
# 0       0  is upset that he can't update his Facebook by ...
# 1       0  @Kenichan I dived many times for the ball. Man...
# 2       0    my whole body feels itchy and like its on fire
# 3       0  @nationwideclass no, it's not behaving at all....
# 4       0                      @Kwesidei not the whole crew

# %%
data_frame.drop(data_frame[data_frame['labels'] == 0].sample(frac=0.70).index)
data_frame = data_frame.drop(data_frame[data_frame['labels'] == 4].sample(frac=0.70).index)
print(data_frame.shape)
# Out:
# (1039999, 2)

# %%
data_frame.head()
# Out:
#    labels                                              tweet
# 0       0  is upset that he can't update his Facebook by ...
# 1       0  @Kenichan I dived many times for the ball. Man...
# 2       0    my whole body feels itchy and like its on fire
# 3       0  @nationwideclass no, it's not behaving at all....
# 4       0                      @Kwesidei not the whole crew

# %%
def remove_stopwords(words):
    stop_words = set(stopwords.words('english'))
    rem = [w for w in words if not w in stop_words]
    return rem

def preprocessing(text):
    words = text.split()
    words = [word for word in words if word.isalpha()]
    rem = remove_stopwords(words)
    return ' '.join(rem)

# %%
data_frame['tweet'] = data_frame['tweet'].apply(preprocessing)
data_frame.head()
# Out:
#    labels                                              tweet
# 0       0  upset update Facebook texting might cry result...
# 1       0  I dived many times Managed save The rest go bo...
# 2       0                   whole body feels itchy like fire
# 3       0                                     behaving I see
# 4       0                                         whole crew

# %%
count = Counter((' ').join(data_frame['tweet']).split())
total_words = len(count)
sorted_words = count.most_common(total_words)
vocab_to_int = {w:i for i, (w,c) in enumerate(sorted_words)}

tweet_arr = []
for tweets in data_frame['tweet']:
    tweet = [vocab_to_int[w] for w in tweets.split()]
    tweet_arr.append(tweet)

print(tweet_arr[:3])
# Out:
# [[513, 438, 1418, 2043, 169, 380, 2580, 1194, 22], [0, 60398, 163, 315, 6576, 725, 33, 379, 3, 48755], [249, 629, 310, 2506, 2, 1377]]

# %%
target = [1 if labels == 4 else 0 for labels in data_frame['labels']]
target_arr = np.array(target)

# %%
def padding_tweets(tweets, sequence):
    total_features = np.zeros((len(tweets), sequence), dtype = int)
    for i, tweet in enumerate(tweets):
        tweet_len = len(tweet)
        if tweet_len <= sequence:
            zeroes = list(np.zeros(sequence-tweet_len))
            new = zeroes+tweet
        elif tweet_len > sequence:
            new = tweet[0:sequence]
        total_features[i,:] = np.array(new)
    return total_features

# %%
features = padding_tweets(tweet_arr, 25)
len_feat = len(features)

print(len_feat)
print(type(features))

split_frac = 0.8
train_x = features[:int(split_frac*len_feat)]
train_y = target_arr[:int(split_frac*len_feat)]
remaining_x = features[int(split_frac*len_feat):]
remaining_y = target_arr[int(split_frac*len_feat):]
valid_x = remaining_x[:int(len(remaining_x)*0.5)]
valid_y = remaining_y[:int(len(remaining_y)*0.5)]
test_x = remaining_x[int(len(remaining_x)*0.5):]
test_y = remaining_y[int(len(remaining_y)*0.5):]
# Out:
# 1039999
# <class 'numpy.ndarray'>

# %%
batch_size = 50

train_data = TensorDataset(torch.from_numpy(np.array(train_x)), torch.from_numpy(np.array(train_y)))
valid_data = TensorDataset(torch.from_numpy(np.array(valid_x)), torch.from_numpy(np.array(valid_y)))
test_data = TensorDataset(torch.from_numpy(np.array(test_x)), torch.from_numpy(np.array(test_y)))
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)
valid_loader = DataLoader(valid_data, shuffle=True, batch_size=batch_size)
test_loader = DataLoader(test_data, shuffle=True, batch_size=batch_size)
dataiter = iter(train_loader)
sample_x, sample_y = next(dataiter)

print('Sample input size: ', sample_x.size()) 
print('Sample input: \n', sample_x)
print()
print('Sample label size: ', sample_y.size())
# Out:
# Sample input size:  torch.Size([50, 25])
# Sample input:
#  tensor([[    0,     0,     0,  ...,    11,   187,    48],
#         [    0,     0,     0,  ...,    40,     1,    69],
#         [    0,     0,     0,  ...,   642,  3587, 48476],
#         ...,
#         [    0,     0,     0,  ...,   151,   218,    65],
#         [    0,     0,     0,  ...,   228,  5865,  1056],
#         [    0,     0,     0,  ...,    60,  8125,  9249]])
#
# Sample label size:  torch.Size([50])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
class GRUNetwork_Q2(nn.Module):
    
    def __init__(self, vocab_size, output_size, embedding_dim, hidden_dim, n_layers, drop_prob=0.5):
        super().__init__()
        self.output_size = output_size
        self.n_layers = n_layers
        self.hidden_dim = hidden_dim
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.GRU(embedding_dim, hidden_dim, n_layers, dropout=drop_prob, batch_first=True)
        self.dropout = nn.Dropout(0.3)
        self.fc = nn.Linear(hidden_dim, output_size)
        self.sig = nn.Sigmoid()

    def forward(self, x, hidden):
        batch_size = x.size(0)
        embeds = self.embedding(x)
        lstm_out, hidden = self.lstm(embeds, hidden)
        lstm_out = lstm_out.contiguous().view(-1, self.hidden_dim)
        out = self.dropout(lstm_out)
        out = self.fc(out)
        sig_out = self.sig(out)
        sig_out = sig_out.view(batch_size, -1)
        sig_out = sig_out[:, -1] 
        return sig_out, hidden
    
    def init_hidden(self, batch_size):
        weight = next(self.parameters()).data
        hidden = weight.new(self.n_layers, batch_size, self.hidden_dim).zero_()
        return hidden

# %%
vocabulary_size = len(vocab_to_int)+1 
output_size = 1
embedding_dims = 400
hidden_dims = 256
num_layers = 2
gru_net = GRUNetwork_Q2(vocabulary_size, output_size, embedding_dims, hidden_dims, num_layers).to(device)
print(gru_net)
# Out:
# GRUNetwork_Q2(
#   (embedding): Embedding(205990, 400)
#   (lstm): GRU(400, 256, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=256, out_features=1, bias=True)
#   (sig): Sigmoid()
# )

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(gru_net.parameters(), lr=0.001)
epochs = 3 
count = 0
epoch_print = 100
clip=5

gru_net.train()

for epoch in range(epochs):
    h = gru_net.init_hidden(batch_size)
    train_num_correct = 0
    for inputs, labels in train_loader:
        count += 1
        if count>(5000*(epoch+1)):
            break
        h = h.data
        gru_net.zero_grad()
        inputs = inputs.type(torch.LongTensor)
        inputs = inputs.to(device)
        labels = labels.to(device)
        output, h = gru_net(inputs, h)
        loss = criterion(output.squeeze(), labels.float())
        loss.backward()
        pred = torch.round(output.squeeze()) 
        train_correct_tensor = pred.eq(labels.float().view_as(pred)).cpu()
        train_correct = np.squeeze(train_correct_tensor.numpy())
        train_num_correct += np.sum(train_correct)
        nn.utils.clip_grad_norm_(gru_net.parameters(), clip)
        optimizer.step()
        if count % epoch_print == 0:
            val_h = gru_net.init_hidden(batch_size)
            val_losses = []
            gru_net.eval()
            val_num_correct = 0
            for inputs, labels in valid_loader:
                val_h = val_h.data
                inputs = inputs.type(torch.LongTensor)
                inputs = inputs.to(device)
                labels = labels.to(device)
                output, val_h = gru_net(inputs, val_h)
                val_loss = criterion(output.squeeze(), labels.float())
                val_losses.append(val_loss.item())
                pred = torch.round(output.squeeze()) 
                val_correct_tensor = pred.eq(labels.float().view_as(pred)).cpu()
                val_correct = np.squeeze(val_correct_tensor.numpy())
                val_num_correct += np.sum(val_correct)
            gru_net.train()
            val_acc = val_num_correct/len(valid_loader.dataset)
            print("Epoch: {}/{} \t".format(epoch+1, epochs),
                  "Step: {} \t".format(count),
                  "Loss: {:.6f} \t".format(loss.item()),
                  "Val Loss: {:.6f} \t".format(np.mean(val_losses)),
                  "Val Accuracy: {:.6f} \t".format(val_acc))
    train_acc = train_num_correct/len(train_loader.dataset)
    print("Train Accuracy: {:.6f}".format(train_acc))
# Out:
# Epoch: 1/3 	 Step: 100 	 Loss: 0.079683 	 Val Loss: 2.687428 	 Val Accuracy: 0.077865
# Epoch: 1/3 	 Step: 200 	 Loss: 0.138392 	 Val Loss: 2.466555 	 Val Accuracy: 0.089125
# Epoch: 1/3 	 Step: 300 	 Loss: 0.246004 	 Val Loss: 2.657064 	 Val Accuracy: 0.067212
# Epoch: 1/3 	 Step: 400 	 Loss: 0.199285 	 Val Loss: 2.766932 	 Val Accuracy: 0.075702
# Epoch: 1/3 	 Step: 500 	 Loss: 0.060889 	 Val Loss: 2.663726 	 Val Accuracy: 0.036375
# Epoch: 1/3 	 Step: 600 	 Loss: 0.239222 	 Val Loss: 2.576798 	 Val Accuracy: 0.086413
# Epoch: 1/3 	 Step: 700 	 Loss: 0.304842 	 Val Loss: 2.686845 	 Val Accuracy: 0.114846
# Epoch: 1/3 	 Step: 800 	 Loss: 0.113358 	 Val Loss: 2.744933 	 Val Accuracy: 0.069433
# Epoch: 1/3 	 Step: 900 	 Loss: 0.235670 	 Val Loss: 2.698611 	 Val Accuracy: 0.039010
# Epoch: 1/3 	 Step: 1000 	 Loss: 0.109358 	 Val Loss: 2.906211 	 Val Accuracy: 0.056731
# Epoch: 1/3 	 Step: 1100 	 Loss: 0.079935 	 Val Loss: 2.954846 	 Val Accuracy: 0.043798
# Epoch: 1/3 	 Step: 1200 	 Loss: 0.196916 	 Val Loss: 3.005407 	 Val Accuracy: 0.056731
# Epoch: 1/3 	 Step: 1300 	 Loss: 0.079824 	 Val Loss: 2.725440 	 Val Accuracy: 0.054202
# Epoch: 1/3 	 Step: 1400 	 Loss: 0.066488 	 Val Loss: 2.353482 	 Val Accuracy: 0.151981
# Epoch: 1/3 	 Step: 1500 	 Loss: 0.328708 	 Val Loss: 2.485854 	 Val Accuracy: 0.065327
# Epoch: 1/3 	 Step: 1600 	 Loss: 0.230263 	 Val Loss: 2.542090 	 Val Accuracy: 0.064106
# Epoch: 1/3 	 Step: 1700 	 Loss: 0.224750 	 Val Loss: 2.893250 	 Val Accuracy: 0.079750
# Epoch: 1/3 	 Step: 1800 	 Loss: 0.203677 	 Val Loss: 2.616095 	 Val Accuracy: 0.082808
# Epoch: 1/3 	 Step: 1900 	 Loss: 0.122951 	 Val Loss: 2.407703 	 Val Accuracy: 0.087038
# Epoch: 1/3 	 Step: 2000 	 Loss: 0.163357 	 Val Loss: 2.301921 	 Val Accuracy: 0.115510
# Epoch: 1/3 	 Step: 2100 	 Loss: 0.027037 	 Val Loss: 2.613517 	 Val Accuracy: 0.062596
# Epoch: 1/3 	 Step: 2200 	 Loss: 0.212167 	 Val Loss: 2.541165 	 Val Accuracy: 0.089519
# Epoch: 1/3 	 Step: 2300 	 Loss: 0.054967 	 Val Loss: 2.689213 	 Val Accuracy: 0.037183
# Epoch: 1/3 	 Step: 2400 	 Loss: 0.208603 	 Val Loss: 2.421035 	 Val Accuracy: 0.093260
# Epoch: 1/3 	 Step: 2500 	 Loss: 0.060088 	 Val Loss: 2.687090 	 Val Accuracy: 0.091231
# Epoch: 1/3 	 Step: 2600 	 Loss: 0.079337 	 Val Loss: 2.433142 	 Val Accuracy: 0.092442
# Epoch: 1/3 	 Step: 2700 	 Loss: 0.068965 	 Val Loss: 2.573503 	 Val Accuracy: 0.046663
# Epoch: 1/3 	 Step: 2800 	 Loss: 0.179597 	 Val Loss: 2.591571 	 Val Accuracy: 0.104087
# Epoch: 1/3 	 Step: 2900 	 Loss: 0.130504 	 Val Loss: 2.702469 	 Val Accuracy: 0.092250
# Epoch: 1/3 	 Step: 3000 	 Loss: 0.125717 	 Val Loss: 2.493767 	 Val Accuracy: 0.083817
# Epoch: 1/3 	 Step: 3100 	 Loss: 0.121839 	 Val Loss: 2.722330 	 Val Accuracy: 0.074865
# Epoch: 1/3 	 Step: 3200 	 Loss: 0.102933 	 Val Loss: 2.454255 	 Val Accuracy: 0.044779
# Epoch: 1/3 	 Step: 3300 	 Loss: 0.248611 	 Val Loss: 2.347806 	 Val Accuracy: 0.092846
# Epoch: 1/3 	 Step: 3400 	 Loss: 0.124093 	 Val Loss: 2.447573 	 Val Accuracy: 0.066260
# Epoch: 1/3 	 Step: 3500 	 Loss: 0.076976 	 Val Loss: 2.377541 	 Val Accuracy: 0.081356
# Epoch: 1/3 	 Step: 3600 	 Loss: 0.116595 	 Val Loss: 2.386308 	 Val Accuracy: 0.111365
# Epoch: 1/3 	 Step: 3700 	 Loss: 0.107641 	 Val Loss: 2.554450 	 Val Accuracy: 0.066365
# Epoch: 1/3 	 Step: 3800 	 Loss: 0.217525 	 Val Loss: 2.411875 	 Val Accuracy: 0.074769
# Epoch: 1/3 	 Step: 3900 	 Loss: 0.067098 	 Val Loss: 2.572462 	 Val Accuracy: 0.065519
# Epoch: 1/3 	 Step: 4000 	 Loss: 0.122494 	 Val Loss: 2.440513 	 Val Accuracy: 0.068817
# Epoch: 1/3 	 Step: 4100 	 Loss: 0.083605 	 Val Loss: 2.517808 	 Val Accuracy: 0.144971
# Epoch: 1/3 	 Step: 4200 	 Loss: 0.228040 	 Val Loss: 2.221414 	 Val Accuracy: 0.138125
# Epoch: 1/3 	 Step: 4300 	 Loss: 0.039102 	 Val Loss: 2.415638 	 Val Accuracy: 0.115058
# Epoch: 1/3 	 Step: 4400 	 Loss: 0.037658 	 Val Loss: 2.629393 	 Val Accuracy: 0.102606
# Epoch: 1/3 	 Step: 4500 	 Loss: 0.083965 	 Val Loss: 2.532633 	 Val Accuracy: 0.109952
# Epoch: 1/3 	 Step: 4600 	 Loss: 0.235108 	 Val Loss: 2.486975 	 Val Accuracy: 0.082558
# Epoch: 1/3 	 Step: 4700 	 Loss: 0.099393 	 Val Loss: 2.540293 	 Val Accuracy: 0.114087
# Epoch: 1/3 	 Step: 4800 	 Loss: 0.053212 	 Val Loss: 2.169852 	 Val Accuracy: 0.098692
# Epoch: 1/3 	 Step: 4900 	 Loss: 0.193965 	 Val Loss: 2.300102 	 Val Accuracy: 0.114577
# Epoch: 1/3 	 Step: 5000 	 Loss: 0.099584 	 Val Loss: 2.348770 	 Val Accuracy: 0.072423
# Train Accuracy: 0.289112
# Epoch: 2/3 	 Step: 5100 	 Loss: 0.149593 	 Val Loss: 2.861594 	 Val Accuracy: 0.068779
# Epoch: 2/3 	 Step: 5200 	 Loss: 0.087602 	 Val Loss: 2.581103 	 Val Accuracy: 0.068077
# Epoch: 2/3 	 Step: 5300 	 Loss: 0.312744 	 Val Loss: 2.696207 	 Val Accuracy: 0.070288
# Epoch: 2/3 	 Step: 5400 	 Loss: 0.132384 	 Val Loss: 2.279653 	 Val Accuracy: 0.096558
# Epoch: 2/3 	 Step: 5500 	 Loss: 0.174476 	 Val Loss: 2.724643 	 Val Accuracy: 0.106692
# Epoch: 2/3 	 Step: 5600 	 Loss: 0.118802 	 Val Loss: 2.639483 	 Val Accuracy: 0.100106
# Epoch: 2/3 	 Step: 5700 	 Loss: 0.049338 	 Val Loss: 2.654270 	 Val Accuracy: 0.094144
# Epoch: 2/3 	 Step: 5800 	 Loss: 0.284988 	 Val Loss: 2.461961 	 Val Accuracy: 0.115087
# Epoch: 2/3 	 Step: 5900 	 Loss: 0.101919 	 Val Loss: 2.426317 	 Val Accuracy: 0.121279
# Epoch: 2/3 	 Step: 6000 	 Loss: 0.067060 	 Val Loss: 3.002472 	 Val Accuracy: 0.057654
# Epoch: 2/3 	 Step: 6100 	 Loss: 0.079377 	 Val Loss: 3.178096 	 Val Accuracy: 0.047769
# Epoch: 2/3 	 Step: 6200 	 Loss: 0.028250 	 Val Loss: 2.776858 	 Val Accuracy: 0.088808
# Epoch: 2/3 	 Step: 6300 	 Loss: 0.060546 	 Val Loss: 2.787661 	 Val Accuracy: 0.068192
# Epoch: 2/3 	 Step: 6400 	 Loss: 0.108904 	 Val Loss: 2.429390 	 Val Accuracy: 0.118317
# Epoch: 2/3 	 Step: 6500 	 Loss: 0.022087 	 Val Loss: 2.898269 	 Val Accuracy: 0.046038
# Epoch: 2/3 	 Step: 6600 	 Loss: 0.397396 	 Val Loss: 2.874627 	 Val Accuracy: 0.089038
# Epoch: 2/3 	 Step: 6700 	 Loss: 0.109229 	 Val Loss: 2.913874 	 Val Accuracy: 0.079962
# Epoch: 2/3 	 Step: 6800 	 Loss: 0.209110 	 Val Loss: 2.463962 	 Val Accuracy: 0.106721
# Epoch: 2/3 	 Step: 6900 	 Loss: 0.170564 	 Val Loss: 2.622957 	 Val Accuracy: 0.095125
# Epoch: 2/3 	 Step: 7000 	 Loss: 0.219224 	 Val Loss: 2.781469 	 Val Accuracy: 0.065548
# Epoch: 2/3 	 Step: 7100 	 Loss: 0.198846 	 Val Loss: 2.975259 	 Val Accuracy: 0.057865
# Epoch: 2/3 	 Step: 7200 	 Loss: 0.060746 	 Val Loss: 2.503877 	 Val Accuracy: 0.115010
# Epoch: 2/3 	 Step: 7300 	 Loss: 0.147995 	 Val Loss: 2.076598 	 Val Accuracy: 0.163529
# Epoch: 2/3 	 Step: 7400 	 Loss: 0.158796 	 Val Loss: 3.125534 	 Val Accuracy: 0.060904
# Epoch: 2/3 	 Step: 7500 	 Loss: 0.120910 	 Val Loss: 2.276446 	 Val Accuracy: 0.113481
# Epoch: 2/3 	 Step: 7600 	 Loss: 0.095946 	 Val Loss: 2.502250 	 Val Accuracy: 0.127971
# Epoch: 2/3 	 Step: 7700 	 Loss: 0.121880 	 Val Loss: 2.559152 	 Val Accuracy: 0.113337
# Epoch: 2/3 	 Step: 7800 	 Loss: 0.108951 	 Val Loss: 2.793799 	 Val Accuracy: 0.071673
# Epoch: 2/3 	 Step: 7900 	 Loss: 0.150491 	 Val Loss: 2.631283 	 Val Accuracy: 0.112490
# Epoch: 2/3 	 Step: 8000 	 Loss: 0.028549 	 Val Loss: 2.611797 	 Val Accuracy: 0.074173
# Epoch: 2/3 	 Step: 8100 	 Loss: 0.099334 	 Val Loss: 2.572306 	 Val Accuracy: 0.113106
# Epoch: 2/3 	 Step: 8200 	 Loss: 0.076657 	 Val Loss: 2.371379 	 Val Accuracy: 0.103856
# Epoch: 2/3 	 Step: 8300 	 Loss: 0.129783 	 Val Loss: 2.638685 	 Val Accuracy: 0.086885
# Epoch: 2/3 	 Step: 8400 	 Loss: 0.054641 	 Val Loss: 2.983007 	 Val Accuracy: 0.082962
# Epoch: 2/3 	 Step: 8500 	 Loss: 0.084468 	 Val Loss: 2.456560 	 Val Accuracy: 0.051308
# Epoch: 2/3 	 Step: 8600 	 Loss: 0.116660 	 Val Loss: 2.800753 	 Val Accuracy: 0.086827
# Epoch: 2/3 	 Step: 8700 	 Loss: 0.049254 	 Val Loss: 2.738183 	 Val Accuracy: 0.069365
# Epoch: 2/3 	 Step: 8800 	 Loss: 0.092922 	 Val Loss: 2.696817 	 Val Accuracy: 0.048337
# Epoch: 2/3 	 Step: 8900 	 Loss: 0.208033 	 Val Loss: 2.847874 	 Val Accuracy: 0.079433
# Epoch: 2/3 	 Step: 9000 	 Loss: 0.109051 	 Val Loss: 2.945397 	 Val Accuracy: 0.062596
# Epoch: 2/3 	 Step: 9100 	 Loss: 0.037459 	 Val Loss: 2.536691 	 Val Accuracy: 0.124769
# Epoch: 2/3 	 Step: 9200 	 Loss: 0.033552 	 Val Loss: 2.510185 	 Val Accuracy: 0.063990
# Epoch: 2/3 	 Step: 9300 	 Loss: 0.220275 	 Val Loss: 2.435300 	 Val Accuracy: 0.125038
# Epoch: 2/3 	 Step: 9400 	 Loss: 0.103053 	 Val Loss: 2.505877 	 Val Accuracy: 0.090077
# Epoch: 2/3 	 Step: 9500 	 Loss: 0.262992 	 Val Loss: 2.442027 	 Val Accuracy: 0.093337
# Epoch: 2/3 	 Step: 9600 	 Loss: 0.276067 	 Val Loss: 2.512078 	 Val Accuracy: 0.065375
# Epoch: 2/3 	 Step: 9700 	 Loss: 0.066092 	 Val Loss: 2.173278 	 Val Accuracy: 0.136115
# Epoch: 2/3 	 Step: 9800 	 Loss: 0.072168 	 Val Loss: 2.648895 	 Val Accuracy: 0.078750
# Epoch: 2/3 	 Step: 9900 	 Loss: 0.208746 	 Val Loss: 2.497092 	 Val Accuracy: 0.088654
# Epoch: 2/3 	 Step: 10000 	 Loss: 0.154428 	 Val Loss: 2.435880 	 Val Accuracy: 0.107519
# Train Accuracy: 0.289143
# Epoch: 3/3 	 Step: 10100 	 Loss: 0.089621 	 Val Loss: 2.525993 	 Val Accuracy: 0.095404
# Epoch: 3/3 	 Step: 10200 	 Loss: 0.105246 	 Val Loss: 2.313889 	 Val Accuracy: 0.118538
# Epoch: 3/3 	 Step: 10300 	 Loss: 0.243099 	 Val Loss: 2.338118 	 Val Accuracy: 0.119375
# Epoch: 3/3 	 Step: 10400 	 Loss: 0.073218 	 Val Loss: 2.488246 	 Val Accuracy: 0.104548
# Epoch: 3/3 	 Step: 10500 	 Loss: 0.148210 	 Val Loss: 2.662048 	 Val Accuracy: 0.072346
# Epoch: 3/3 	 Step: 10600 	 Loss: 0.171060 	 Val Loss: 2.589565 	 Val Accuracy: 0.095096
# Epoch: 3/3 	 Step: 10700 	 Loss: 0.174694 	 Val Loss: 2.469032 	 Val Accuracy: 0.118606
# Epoch: 3/3 	 Step: 10800 	 Loss: 0.268074 	 Val Loss: 2.604807 	 Val Accuracy: 0.114529
# Epoch: 3/3 	 Step: 10900 	 Loss: 0.048940 	 Val Loss: 2.601363 	 Val Accuracy: 0.135394
# Epoch: 3/3 	 Step: 11000 	 Loss: 0.237454 	 Val Loss: 2.721683 	 Val Accuracy: 0.103663
# Epoch: 3/3 	 Step: 11100 	 Loss: 0.090620 	 Val Loss: 2.845147 	 Val Accuracy: 0.091981
# Epoch: 3/3 	 Step: 11200 	 Loss: 0.235201 	 Val Loss: 2.423513 	 Val Accuracy: 0.109221
# Epoch: 3/3 	 Step: 11300 	 Loss: 0.106199 	 Val Loss: 2.721297 	 Val Accuracy: 0.069827
# Epoch: 3/3 	 Step: 11400 	 Loss: 0.110980 	 Val Loss: 2.814204 	 Val Accuracy: 0.061212
# Epoch: 3/3 	 Step: 11500 	 Loss: 0.033709 	 Val Loss: 2.921361 	 Val Accuracy: 0.080817
# Epoch: 3/3 	 Step: 11600 	 Loss: 0.046094 	 Val Loss: 2.958719 	 Val Accuracy: 0.056538
# Epoch: 3/3 	 Step: 11700 	 Loss: 0.343584 	 Val Loss: 2.679232 	 Val Accuracy: 0.078952
# Epoch: 3/3 	 Step: 11800 	 Loss: 0.228940 	 Val Loss: 2.329752 	 Val Accuracy: 0.131212
# Epoch: 3/3 	 Step: 11900 	 Loss: 0.363223 	 Val Loss: 2.415586 	 Val Accuracy: 0.119250
# Epoch: 3/3 	 Step: 12000 	 Loss: 0.077188 	 Val Loss: 2.681047 	 Val Accuracy: 0.112163
# Epoch: 3/3 	 Step: 12100 	 Loss: 0.157745 	 Val Loss: 2.310816 	 Val Accuracy: 0.102413
# Epoch: 3/3 	 Step: 12200 	 Loss: 0.110352 	 Val Loss: 2.355919 	 Val Accuracy: 0.128538
# Epoch: 3/3 	 Step: 12300 	 Loss: 0.106121 	 Val Loss: 2.499706 	 Val Accuracy: 0.100346
# Epoch: 3/3 	 Step: 12400 	 Loss: 0.150577 	 Val Loss: 2.393033 	 Val Accuracy: 0.124865
# Epoch: 3/3 	 Step: 12500 	 Loss: 0.035568 	 Val Loss: 2.559198 	 Val Accuracy: 0.128077
# Epoch: 3/3 	 Step: 12600 	 Loss: 0.039778 	 Val Loss: 2.652882 	 Val Accuracy: 0.092375
# Epoch: 3/3 	 Step: 12700 	 Loss: 0.070696 	 Val Loss: 2.507123 	 Val Accuracy: 0.115212
# Epoch: 3/3 	 Step: 12800 	 Loss: 0.152586 	 Val Loss: 2.421063 	 Val Accuracy: 0.119077
# Epoch: 3/3 	 Step: 12900 	 Loss: 0.228473 	 Val Loss: 2.271768 	 Val Accuracy: 0.122990
# Epoch: 3/3 	 Step: 13000 	 Loss: 0.130284 	 Val Loss: 2.509985 	 Val Accuracy: 0.113010
# Epoch: 3/3 	 Step: 13100 	 Loss: 0.039565 	 Val Loss: 2.223915 	 Val Accuracy: 0.115731
# Epoch: 3/3 	 Step: 13200 	 Loss: 0.354237 	 Val Loss: 2.754590 	 Val Accuracy: 0.114413
# Epoch: 3/3 	 Step: 13300 	 Loss: 0.071656 	 Val Loss: 2.443887 	 Val Accuracy: 0.092673
# Epoch: 3/3 	 Step: 13400 	 Loss: 0.066615 	 Val Loss: 2.710177 	 Val Accuracy: 0.074317
# Epoch: 3/3 	 Step: 13500 	 Loss: 0.044800 	 Val Loss: 2.690917 	 Val Accuracy: 0.064654
# Epoch: 3/3 	 Step: 13600 	 Loss: 0.163903 	 Val Loss: 2.539141 	 Val Accuracy: 0.084462
# Epoch: 3/3 	 Step: 13700 	 Loss: 0.239233 	 Val Loss: 2.443438 	 Val Accuracy: 0.093596
# Epoch: 3/3 	 Step: 13800 	 Loss: 0.103839 	 Val Loss: 2.739242 	 Val Accuracy: 0.077750
# Epoch: 3/3 	 Step: 13900 	 Loss: 0.128119 	 Val Loss: 2.413610 	 Val Accuracy: 0.085846
# Epoch: 3/3 	 Step: 14000 	 Loss: 0.119788 	 Val Loss: 2.984701 	 Val Accuracy: 0.084375
# Epoch: 3/3 	 Step: 14100 	 Loss: 0.328407 	 Val Loss: 2.647138 	 Val Accuracy: 0.105894
# Epoch: 3/3 	 Step: 14200 	 Loss: 0.085309 	 Val Loss: 2.653418 	 Val Accuracy: 0.081904
# Epoch: 3/3 	 Step: 14300 	 Loss: 0.119247 	 Val Loss: 2.496931 	 Val Accuracy: 0.061519
# Epoch: 3/3 	 Step: 14400 	 Loss: 0.210393 	 Val Loss: 2.786800 	 Val Accuracy: 0.042894
# Epoch: 3/3 	 Step: 14500 	 Loss: 0.111150 	 Val Loss: 2.671118 	 Val Accuracy: 0.136135
# Epoch: 3/3 	 Step: 14600 	 Loss: 0.193732 	 Val Loss: 2.669499 	 Val Accuracy: 0.057385
# Epoch: 3/3 	 Step: 14700 	 Loss: 0.090564 	 Val Loss: 2.862690 	 Val Accuracy: 0.075731
# Epoch: 3/3 	 Step: 14800 	 Loss: 0.112505 	 Val Loss: 2.837616 	 Val Accuracy: 0.077394
# Epoch: 3/3 	 Step: 14900 	 Loss: 0.184512 	 Val Loss: 2.789395 	 Val Accuracy: 0.097750
# Epoch: 3/3 	 Step: 15000 	 Loss: 0.093918 	 Val Loss: 2.481878 	 Val Accuracy: 0.103904
# Train Accuracy: 0.289160

# %%
test_losses = [] 
num_correct = 0
h = gru_net.init_hidden(batch_size)
gru_net.eval()
for inputs, labels in test_loader:
    h = h.data
    inputs = inputs.type(torch.LongTensor)
    inputs = inputs.to(device)
    labels = labels.to(device)
    output, h = gru_net(inputs, h)
    test_loss = criterion(output.squeeze(), labels.float())
    test_losses.append(test_loss.item())
    pred = torch.round(output.squeeze())
    correct_tensor = pred.eq(labels.float().view_as(pred)).cpu()
    correct = np.squeeze(correct_tensor.numpy())
    num_correct += np.sum(correct)
print("Test Data loss is : {:.3f}".format(np.mean(test_losses)))
test_acc = num_correct/len(test_loader.dataset)
print("Test Data accuracy is : {:.3f}".format(test_acc))
# Out:
# Test Data loss is : 2.504
# Test Data accuracy is : 0.097

# %%
def tweet_tokenize(test_tweet):
    test_tweet = test_tweet.lower()
    test_tweet = test_tweet.replace('[^\w\s]','')
    test_words = test_tweet.split()
    test_ints = []
    test_ints.append([vocab_to_int[word] for word in test_words if word in vocab_to_int])
    return test_ints

def predict_sentiment(gru_net, test_tweet, sequence_length = 25):    
    gru_net.eval()
    test_ints = tweet_tokenize(test_tweet)
    seq_length = sequence_length
    features = padding_tweets(test_ints, seq_length)
    feature_tensor = torch.from_numpy(features).to(device)
    batch_size = feature_tensor.size(0)
    h = gru_net.init_hidden(batch_size)
    output, h = gru_net(feature_tensor, h)
    pred = torch.round(output.squeeze()) 
    print("Test Tweet is: ",test_tweet)
    print('Predicted value is : {:.6f}'.format(1-output.item()))
    print("\n")
    if(pred.item()==0):
        print("Positive tweet detected !!")
    else:
        print("Negative tweet detected !!")

# %%
test_tweet = 'Ronaldo will win this Euro Cup for Portugal.'
predict_sentiment(gru_net, test_tweet)
print("\n")
test_tweet = 'India is playing very well in this tournament.'
predict_sentiment(gru_net, test_tweet)
print("\n")
test_tweet = 'The new Marvel move was very disappointing.'
predict_sentiment(gru_net, test_tweet)
# Out:
# Test Tweet is:  Ronaldo will win this Euro Cup for Portugal.
# Predicted value is : 0.925413
#
#
# Positive tweet detected !!
#
#
# Test Tweet is:  India is playing very well in this tournament.
# Predicted value is : 0.944563
#
#
# Positive tweet detected !!
#
#
# Test Tweet is:  The new Marvel move was very disappointing.
# Predicted value is : 0.480344
#
#
# Negative tweet detected !!
